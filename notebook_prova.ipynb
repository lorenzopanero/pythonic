# %%
a = 8
type(a)
# Out:
# int

# %%
b = "Cos'è questa cosa?"
type(b)
# Out:
# str

# %%
c = 7.7
type(c)
# Out:
# float

# %%
d = [1, 2, 3, 4, 5]
type(d)
# Out:
# list

# %%
type(d[0])
# Out:
# int

# %%
d
# Out:
# [1, 2, 3, 4, 5]

# %%
d[1]
# Out:
# 2

# %%
d = [a,b,c]

# %%
type(d)
# Out:
# list

# %%
print(d)
# Out:
# [8, "Cos'è questa cosa?", 7.7]
